# %%
from typing import List, Dict, Optional
import numpy as np
from pathlib import Path
import os

# %%
class GenerateAnswers():
    def __init__(self, query, query_embedding, top_k, model):
        self.query = query
        self.query_embedding = query_embedding
        self.top_k = top_k
        self.model = model
            

    def search_with_explanation(self, query : str, query_embedding : np.ndarray, top_k : int = 5):
        """검색 결과와 설명을 함께 반환"""
        results = self.search(query, query_embedding, top_k)
        explanation = self.search_engine ### 답 생성해주는 함수 구성

        return results, explanation
